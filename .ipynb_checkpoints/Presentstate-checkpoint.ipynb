# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Data1.csv')

# %%
df.shape
# Out:
# (206, 23)

# %%
df.Teacher.value_counts()
# Out:
# 1    137
# 0     69
# Name: Teacher, dtype: int64

# %%
df.head()
# Out:
#             Full_Name       Age  Gender Family_type Family_background  \
# 0      Ramesh Niraula  Below 30    Male       Small      Middle class
# 1      Vijaya Niroula  Below 30  Female       Small      Middle class
# 2  Aishwarya Tandukar  Below 30  Female       Small      Middle class
# 3     Amrita Bhandari  Below 30  Female       Small      Middle class
# 4          Muna dahal  Below 30  Female       Small      Middle class
#
#   Person_type  Friends        B_nch Student_type Relation_teacher  ...  \
# 0   Extrovert        4  Middle rows      Average             Good  ...
# 1   Introvert        4    Last rows      Average             Good  ...
# 2   Introvert        4  Middle rows      Average             Good  ...
# 3   Extrovert        4   First rows  Hard worker        Very good  ...
# 4   Extrovert        5   First rows  Hard worker        Very good  ...
#
#   Usual_rank Extra_activities Presentation  Tours     Remark_8    Remark_10  \
# 0         12         Frequent            1      4  Distinction        First
# 1          5         Frequent            3      5  Distinction  Distinction
# 2         12        Sometimes            3      5        First        First
# 3          1         Frequent            3      1        First        First
# 4          5         Frequent            1      0  Distinction        First
#
#    Remark_Bach Inspired Teacher_family Teacher
# 0       Second       No             No       1
# 1  Distinction      Yes            Yes       1
# 2       Second      Yes             No       1
# 3       Second      Yes            Yes       1
# 4       Second      Yes             No       1
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 23 columns):
# Full_Name            206 non-null object
# Age                  206 non-null object
# Gender               206 non-null object
# Family_type          206 non-null object
# Family_background    206 non-null object
# Person_type          206 non-null object
# Friends              206 non-null int64
# B_nch                206 non-null object
# Student_type         206 non-null object
# Relation_teacher     206 non-null object
# Decision             206 non-null object
# Leadershipness       206 non-null object
# Helping              206 non-null object
# Usual_rank           206 non-null int64
# Extra_activities     206 non-null object
# Presentation         206 non-null int64
# Tours                206 non-null int64
# Remark_8             206 non-null object
# Remark_10            206 non-null object
# Remark_Bach          206 non-null object
# Inspired             206 non-null object
# Teacher_family       206 non-null object
# Teacher              206 non-null int64
# dtypes: int64(5), object(18)
# memory usage: 37.1+ KB

# %%
df.replace({'Below 30': 0,'Below 40': 1,'Below 50': 2,'Below 60': 3,'Female': 0, 'Male': 1, 'Other':2,'Small': 0,'Joint': 1,
           'Low class':0, 'Middle class':1, 'High class':2, 'Introvert':0, 'Extrovert':1,'First rows':0,'Middle rows':1,'Last rows':2,
           'Hard worker':0, 'Average':1, 'Negligent':2, 'Good':0, 'Bad':1, 'Very good':2,'Sometimes':0,'Frequent':1, 'Never':2,
            'Distinction':0, 'First':1, 'Second':2, 'Third':3, 'Yes':1,'No':0},inplace = True)
df.drop(['Full_Name'],axis =1, inplace = True)
df.head()
# Out:
#    Age  Gender  Family_type  Family_background  Person_type  Friends  B_nch  \
# 0    0       1            0                  1            1        4      1
# 1    0       0            0                  1            0        4      2
# 2    0       0            0                  1            0        4      1
# 3    0       0            0                  1            1        4      0
# 4    0       0            0                  1            1        5      0
#
#    Student_type  Relation_teacher  Decision  ...  Usual_rank  \
# 0             1                 0         1  ...          12
# 1             1                 0         0  ...           5
# 2             1                 0         0  ...          12
# 3             0                 2         0  ...           1
# 4             0                 2         0  ...           5
#
#    Extra_activities  Presentation  Tours  Remark_8  Remark_10  Remark_Bach  \
# 0                 1             1      4         0          1            2
# 1                 1             3      5         0          0            0
# 2                 0             3      5         1          1            2
# 3                 1             3      1         1          1            2
# 4                 1             1      0         0          1            2
#
#    Inspired  Teacher_family  Teacher
# 0         0               0        1
# 1         1               1        1
# 2         1               0        1
# 3         1               1        1
# 4         1               0        1
#
# [5 rows x 22 columns]

# %%
#df.drop(['Teache_Family','Extra_activities','Leadershipness','Bench'],axis = 1, inplace= True)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Family_type', 'Family_background', 'Person_type',
#        'Friends', 'B_nch', 'Student_type', 'Relation_teacher', 'Decision',
#        'Leadershipness', 'Helping', 'Usual_rank', 'Extra_activities',
#        'Presentation', 'Tours', 'Remark_8', 'Remark_10', 'Remark_Bach',
#        'Inspired', 'Teacher_family', 'Teacher'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 22 columns):
# Age                  206 non-null int64
# Gender               206 non-null int64
# Family_type          206 non-null int64
# Family_background    206 non-null int64
# Person_type          206 non-null int64
# Friends              206 non-null int64
# B_nch                206 non-null int64
# Student_type         206 non-null int64
# Relation_teacher     206 non-null int64
# Decision             206 non-null int64
# Leadershipness       206 non-null int64
# Helping              206 non-null int64
# Usual_rank           206 non-null int64
# Extra_activities     206 non-null int64
# Presentation         206 non-null int64
# Tours                206 non-null int64
# Remark_8             206 non-null int64
# Remark_10            206 non-null int64
# Remark_Bach          206 non-null int64
# Inspired             206 non-null int64
# Teacher_family       206 non-null int64
# Teacher              206 non-null int64
# dtypes: int64(22)
# memory usage: 35.5 KB

# %%
#df.drop(['Teacher_family','Extra_activities','Leadershipness','B_nch','Helping','Family_background','Gender'],axis = 1, inplace= True)
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),annot = True)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Teacher', axis = 1)

# %%
y = df['Teacher']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, rfc_pred))
print('\n')
print(classification_report(y_test, rfc_pred))
print('\n')
print(accuracy_score(y_test, rfc_pred))
# Out:
# [[ 8  6]
#  [ 2 26]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67        14
#            1       0.81      0.93      0.87        28
#
#     accuracy                           0.81        42
#    macro avg       0.81      0.75      0.77        42
# weighted avg       0.81      0.81      0.80        42
#
#
#
# 0.8095238095238095

# %%
#from sklearn.externals import joblib

# %%
#joblib.dump(rfc, 'modelrfc')
# Out:
# ['modelrfc']

# %%
#newmod = joblib.load('modelrfc')

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
select_feature = SelectKBest(chi2, k =5).fit(X_train, y_train)

# %%
select_features_df = pd.DataFrame({'Feature':list(X_train.columns), 'Scores':select_feature.scores_})

# %%
select_features_df.sort_values(by = 'Scores',ascending = False)
# Out:
#               Feature     Scores
# 15              Tours  82.806747
# 0                 Age  25.382468
# 5             Friends  14.429471
# 17          Remark_10  13.779512
# 9            Decision   5.116292
# 16           Remark_8   5.100284
# 18        Remark_Bach   4.290569
# 1              Gender   3.704718
# 12         Usual_rank   3.515231
# 11            Helping   2.935804
# 10     Leadershipness   1.668098
# 13   Extra_activities   1.430987
# 6               B_nch   1.309448
# 2         Family_type   1.149285
# 20     Teacher_family   0.619361
# 14       Presentation   0.241822
# 8    Relation_teacher   0.041807
# 19           Inspired   0.040367
# 3   Family_background   0.031974
# 7        Student_type   0.026436
# 4         Person_type   0.015487

# %%
X_train_chi = select_feature.transform(X_train)
X_test_chi = select_feature.transform(X_test)

# %%
X_train.head(5)
# Out:
#      Age  Gender  Family_type  Family_background  Person_type  Friends  B_nch  \
# 55     0       1            0                  1            1       12      0
# 61     2       1            1                  1            1       30      0
# 189    0       0            0                  1            1        3      2
# 177    0       0            0                  1            1       18      0
# 110    0       1            0                  0            1        5      0
#
#      Student_type  Relation_teacher  Decision  ...  Helping  Usual_rank  \
# 55              0                 2         0  ...        2           2
# 61              0                 0         1  ...        0           5
# 189             1                 0         0  ...        2          15
# 177             0                 2         0  ...        2          60
# 110             0                 2         1  ...        2          29
#
#      Extra_activities  Presentation  Tours  Remark_8  Remark_10  Remark_Bach  \
# 55                  0             3     20         0          0            1
# 61                  0             3      5         2          2            2
# 189                 2             3     17         0          0            0
# 177                 1             4      3         0          0            0
# 110                 0             2     10         0          0            1
#
#      Inspired  Teacher_family
# 55          1               1
# 61          1               1
# 189         1               0
# 177         1               0
# 110         1               0
#
# [5 rows x 21 columns]

# %%
X_train_chi[0:5]
# Out:
# array([[ 0, 12,  0, 20,  0],
#        [ 2, 30,  1,  5,  2],
#        [ 0,  3,  0, 17,  0],
#        [ 0, 18,  0,  3,  0],
#        [ 0,  5,  1, 10,  0]], dtype=int64)

# %%
rfc.fit(X_train_chi,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred2 = rfc.predict(X_test_chi)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, rfc_pred2))
print('\n')
print(classification_report(y_test, rfc_pred2))
print('\n')
print(accuracy_score(y_test, rfc_pred2))
# Out:
# [[ 7  7]
#  [ 5 23]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.50      0.54        14
#            1       0.77      0.82      0.79        28
#
#     accuracy                           0.71        42
#    macro avg       0.68      0.66      0.67        42
# weighted avg       0.71      0.71      0.71        42
#
#
#
# 0.7142857142857143
